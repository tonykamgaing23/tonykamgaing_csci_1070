# %%
# %pip install matplotlib
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.3/8.3 MB 12.5 MB/s eta 0:00:0000:0100:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.9/4.9 MB 18.2 MB/s eta 0:00:00a 0:00:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.5/1.5 MB 18.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.5/4.5 MB 10.9 MB/s eta 0:00:0000:01
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
CSCI_listings = "CSCI_Fall_2024_survey.csv"
survey_df = pd.read_csv(CSCI_listings)
survey_df.tail()
# Out:
#                     Timestamp What is your name? What are your pronouns?  \
# 21  2024/09/05 6:40:43 PM EST              Drake                  He/Him
# 22  2024/09/05 6:41:20 PM EST              Isaac                  He/Him
# 23  2024/09/05 6:42:17 PM EST               Tony                  He/Him
# 24  2024/09/05 6:51:00 PM EST               Esme                 She/Her
# 25  2024/09/05 6:59:20 PM EST               Alan                  He/Him
#
#    What state/country were you born in?  How many siblings do you have?  \
# 21           People's Republic of China                               4
# 22                                india                               3
# 23                             Cameroon                               2
# 24                                TEXAS                               4
# 25                           Kazakhstah                               3
#
#    How much experience do you have programming? What class are you in?   \
# ...

# %%
import pandas as pd

df = pd.DataFrame({'What is your name': ['Drake', 'Issac', 'Tony', 'Esme', 'Alan'],
                   'What state/country were you born in': ['Peoples Republic of China', 'india', 'Cameroon', 'TEXAS', 'Kazakhstah']})

print(df)
# Out:
#   What is your name What state/country were you born in
# 0             Drake           Peoples Republic of China
# 1             Issac                               india
# 2              Tony                            Cameroon
# 3              Esme                               TEXAS
# 4              Alan                          Kazakhstah

# %%
survey_df.loc[survey_df["What state/country were you born in?"] == "st.louis, mo", "What state/country were you born in?"] = "Missouri"
survey_df.loc[survey_df["What state/country were you born in?"] == "st. louis, mo", "What state/country were you born in?"] = "Missouri"
survey_df.loc[survey_df["What state/country were you born in?"] == "", "What state/country were you born in?"] = "Missouri"
survey_df.loc[survey_df["What state/country were you born in?"] == "", "What state/country were you born in?"] = "Missouri"
survey_df.loc[survey_df["What state/country were you born in?"] == "Missouri, USA", "What state/country were you born in?"] = "Missouri"
survey_df.loc[survey_df["What state/country were you born in?"] == "Georgia (the country not the state)", "What state/country were you born in?"] = "Missouri"
survey_df.loc[survey_df["What state/country were you born in?"] == "Frankfurt, Germany", "What state/country were you born in?"] = "Germany"
survey_df.loc[survey_df["What state/country were you born in?"] == "Saint Louis, Missouri", "What state/country were you born in?"] = "Missouri"
survey_df.loc[survey_df["What state/country were you born in?"] == "Kansas, Overland Park", "What state/country were you born in?"] = "Kansas"
survey_df.loc[survey_df["What state/country were you born in?"] == "United States Missouri", "What state/country were you born in?"] = "Missouri"
survey_df.loc[survey_df["What state/country were you born in?"] == "St. Louis MO", "What state/country were you born in?"] = "Missouri"
survey_df.loc[survey_df["What state/country were you born in?"] == "I was born in Chandigarh, India", "What state/country were you born in?"] = "India"
survey_df.loc[survey_df["What state/country were you born in?"] == "People's Republic of China", "What state/country were you born in?"] = "China"
survey_df.loc[survey_df["What state/country were you born in?"] == "india", "What state/country were you born in?"] = "India"
survey_df.loc[survey_df["What state/country were you born in?"] == "TEXAS", "What state/country were you born in?"] = "Texas"

survey_df.loc[survey_df["What is your major?"] == "Computer Science, B.A. (I might switch to B.S., but I wish to pursue a career in digital IP law, eventually!)", "What is your major?"] = "Computer Science"
survey_df.loc[survey_df["What is your major?"] == "CS/Business", "What is your major?"] = "CS/Business"
survey_df.loc[survey_df["What is your major?"] == "computer science", "What is your major?"] = "Computer Science"
survey_df.loc[survey_df["What is your major?"] == "cs/finance", "What is your major?"] = "CS/Finance"
survey_df.loc[survey_df["What is your major?"] == "Computer Science; considering an additional major or a minor", "What is your major?"] = "Computer Science"
survey_df.loc[survey_df["What is your major?"] == "comp sci", "What is your major?"] = "Computer Science"
survey_df.loc[survey_df["What is your major?"] == "Data science", "What is your major?"] = "Data Science"
survey_df.loc[survey_df["What is your major?"] == "", "What is your major?"] = "Texas"
survey_df.loc[survey_df["What is your major?"] == "Biology w/ evolutionary bio minor", "What is your major?"] = "Biology"
survey_df.loc[survey_df["What is your major?"] == "cs/ finace", "What is your major?"] = "CS/Finance"
survey_df.loc[survey_df["What is your major?"] == "all of the above", "What is your major?"] = "Everything"

survey_df.loc[survey_df["What is your favorite type of food?"] == "korean", "What is your favorite type of food?"] = "Korean"
survey_df.loc[survey_df["What is your favorite type of food?"] == "all of the above", "What is your favorite type of food?"] = "All of the above"


survey_df.loc[survey_df["How many pets and of which kind do you have?"] == "no pets", "How many pets and of which kind do you have?"] = "0"
survey_df.loc[survey_df["How many pets and of which kind do you have?"] == "No pets", "How many pets and of which kind do you have?"] = "0"
survey_df.loc[survey_df["How many pets and of which kind do you have?"] == "no pets!", "How many pets and of which kind do you have?"] = "0"
survey_df.loc[survey_df["How many pets and of which kind do you have?"] == "none", "How many pets and of which kind do you have?"] = "0"
survey_df.loc[survey_df["How many pets and of which kind do you have?"] == "N/A", "How many pets and of which kind do you have?"] = "0"
survey_df.loc[survey_df["How many pets and of which kind do you have?"] == "None:(But I really want a cat", "How many pets and of which kind do you have?"] = "None"
survey_df.loc[survey_df["How many pets and of which kind do you have?"] == "1, Dog", "How many pets and of which kind do you have?"] = "1 Dog"
survey_df.loc[survey_df["How many pets and of which kind do you have?"] == "I have two dogs and they are both at home", "How many pets and of which kind do you have?"] = "2 Dogs"
survey_df.loc[survey_df["How many pets and of which kind do you have?"] == "1 dog and 1 cat", "How many pets and of which kind do you have?"] = "1 Dog and Cat"
survey_df.loc[survey_df["How many pets and of which kind do you have?"] == "2 cats, one dog", "How many pets and of which kind do you have?"] = "2 Cats 1 Dog"
survey_df.loc[survey_df["How many pets and of which kind do you have?"] == "I have two dogs. They're bernedoodles.", "How many pets and of which kind do you have?"] = "2 Dogs"
survey_df.loc[survey_df["How many pets and of which kind do you have?"] == "2, Grumpy the exotic shorthair w heterchromia and my dog Furball is a rescue but he is just as cute", "How many pets and of which kind do you have?"] = "2 Dogs"
survey_df.loc[survey_df["How many pets and of which kind do you have?"] == "2 minature schnauzers", "How many pets and of which kind do you have?"] = "2 Dogs"
survey_df.loc[survey_df["How many pets and of which kind do you have?"] == "2 dogs", "How many pets and of which kind do you have?"] = "2 Dogs"
survey_df.loc[survey_df["How many pets and of which kind do you have?"] == "1 Cat; 6 Dogs (Over two households)", "How many pets and of which kind do you have?"] = "1 Cat 6 Dogs"
survey_df.loc[survey_df["How many pets and of which kind do you have?"] == "had 8 dogs, not anymore", "How many pets and of which kind do you have?"] = "0"
survey_df.loc[survey_df["How many pets and of which kind do you have?"] == "three dogs", "How many pets and of which kind do you have?"] = "3 Dogs"

# %%
survey_df.head()
# Out:
#                    Timestamp What is your name? What are your pronouns?  \
# 0  2024/09/05 6:10:09 PM EST               Alex                  He/Him
# 1  2024/09/05 6:33:51 PM EST              Tanay                  He/Him
# 2  2024/09/05 6:34:21 PM EST            Akshita                 She/Her
# 3  2024/09/05 6:35:03 PM EST            Anthony                  He/Him
# 4  2024/09/05 6:35:56 PM EST               Nuri                  He/Him
#
#   What state/country were you born in?  How many siblings do you have?  \
# 0                               Mexico                               1
# 1                             Missouri                               1
# 2                              Germany                               1
# 3                            Wisconsin                               1
# 4                             Missouri                               2
#
#   How much experience do you have programming? What class are you in?   \
# ...

# %%
survey_df
# Out:
#                     Timestamp What is your name?  \
# 0   2024/09/05 6:10:09 PM EST               Alex
# 1   2024/09/05 6:33:51 PM EST              Tanay
# 2   2024/09/05 6:34:21 PM EST            Akshita
# 3   2024/09/05 6:35:03 PM EST            Anthony
# 4   2024/09/05 6:35:56 PM EST               Nuri
# 5   2024/09/05 6:35:57 PM EST             Mahley
# 6   2024/09/05 6:36:02 PM EST             Chetan
# 7   2024/09/05 6:36:13 PM EST             Steven
# 8   2024/09/05 6:36:14 PM EST               Nico
# 9   2024/09/05 6:36:24 PM EST             Iovane
# 10  2024/09/05 6:36:36 PM EST            Brandon
# 11  2024/09/05 6:36:48 PM EST             Carter
# 12  2024/09/05 6:37:04 PM EST              Tanav
# 13  2024/09/05 6:37:23 PM EST           Abhishek
# 14  2024/09/05 6:37:32 PM EST              Garlo
# 15  2024/09/05 6:37:33 PM EST              Vivek
# 16  2024/09/05 6:37:43 PM EST          Abhilasha
# 17  2024/09/05 6:38:14 PM EST               Tony
# ...

# %%
x = np.array(["0-3 months", "4-6 months", "6 months-1 year", "1-2 years", "2+ years"])
y = np.array([14, 3, 3, 4, 2])

plt.bar(x,y)
plt.show()

# This represent the expierence for the whole class and how much prior knowledge that they had.

# %%
y = np.array([5, 5, 7, 3, 2, 3, 1, 1,  ])
mylabels = ["Mexican", "Japanese","Italian","American","Chinese","Indian","korean","all of the above"]

plt.pie(y, labels = mylabels)
plt.show()
# This show the majority of the class likes Japanese, Italian, and Mexican food.

# %%
x = np.array(["Freshman", "Sophomore", "Junior", "Senior"])
y = np.array([22, 2, 1, 1])

plt.bar(x,y)
plt.show()

# This show what grade everyone in the class is in

# %%
x = np.array([])
y = np.array([])

plt.scatter(x, y)
plt.show()

# This shows both the ages and the amount of siblings everyone in the class has.
# Out:
# <Axes: >

# %%
x = np.array(["On campus", "Off Campus"])
y = np.array([20, 6])

plt.bar(x,y)
plt.show()
# This represents the amount of students live off and on campus.
